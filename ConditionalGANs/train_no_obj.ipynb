# %%
from src.wgan import WassersteinGAN

from src.utils.make_discriminator import make_discriminator
from src.utils.make_generator import make_generator

# %% [markdown]
# ### Data

# %%
def get_data():
    import pickle

    with open('data/new_data_no_obj.pkl', 'rb') as f:
        X_train, cX_train, X_train_z = pickle.load(f)

    # split the training set into training and validation
    n_sample_train = int(X_train.shape[0] * 0.8)

    X_train, X_val = X_train[:n_sample_train], X_train[n_sample_train:]
    cX_train, cX_val = cX_train[:n_sample_train], cX_train[n_sample_train:]
    X_train_z, X_val_z = X_train_z[:n_sample_train], X_train_z[n_sample_train:]

    len_input_seq = X_train.shape[1] # 6
    len_generated_seq = 6

    return X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq

X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq = get_data()

# %% [markdown]
# ### Models

# %%
generator = make_generator(
    image_dim=[3, 64, 64],
    latent_dim=1280,
    conditions_dim=6,
    len_input_seq=len_input_seq,
    len_output_seq=len_generated_seq,
    n_filters=[16, 8, 8, 16],
    kernel_size=[8, 5, 3, 1],
    stride=[3, 1, 1, 1],
    padding=['same', 'same', 'same', 'same'],
    hidden_dims=[128, 128],
)
#generator = load_model('generator_pretrained.h5')

discriminator = make_discriminator(
    input_dim=[3, 64, 64],
    len_input_seq=min(len_input_seq, len_generated_seq),
)

gan = WassersteinGAN(
    generator=generator,
    discriminator=discriminator,
    len_input_seq=len_input_seq,
    len_generated_seq=len_generated_seq,
    patience=3,
    learning_rate_generator=0.01,
    learning_rate_discriminator=0.01,
    n_critic=5,  # number of critic updates per generator update
    clip_value=0.01,
    discriminator_gradient_penalty_weight=0.02,
    generator_wloss_weight=0.2,
    generator_flow_loss_weight=0.15,
    generator_mse_weight=0.6,
    color_weight=0.05,
    save_path = 'wgan_train_no_obj'
)

# %% [markdown]
# ### Train

# %%
gan.train(
    X_train_z, X_train, cX_train, # noise, real images, conditions
    X_val_z, X_val, cX_val,
    epochs=50, batch_size=32
)
# Out:
# Epoch 1/50
# Batch 1/17 - Generator Loss: 0.3018591105937958, Discriminator Loss: 1.0315722227096558
# Batch 2/17 - Generator Loss: 0.3495229482650757, Discriminator Loss: 1.184893250465393
# Batch 3/17 - Generator Loss: 0.35970592498779297, Discriminator Loss: 0.9482831954956055
# Batch 4/17 - Generator Loss: 0.36216264963150024, Discriminator Loss: 0.957903265953064
# Batch 5/17 - Generator Loss: 0.364186555147171, Discriminator Loss: 0.9006219506263733
# Batch 6/17 - Generator Loss: 0.3631916642189026, Discriminator Loss: 0.9061277508735657
# Batch 7/17 - Generator Loss: 0.3601459264755249, Discriminator Loss: 0.937942624092102
# Batch 8/17 - Generator Loss: 0.36384567618370056, Discriminator Loss: 0.8921741843223572
# Batch 9/17 - Generator Loss: 0.36174437403678894, Discriminator Loss: 0.9130497574806213
# Batch 10/17 - Generator Loss: 0.3591146767139435, Discriminator Loss: 0.905754804611206
# Batch 11/17 - Generator Loss: 0.35771897435188293, Discriminator Loss: 0.9232550859451294
# Batch 12/17 - Generator Loss: 0.35940808057785034, Discriminator Loss: 0.933085024356842
# Batch 8/17 - Generator Loss: 0.006138451397418976, Discriminator Loss: 1.242006778717041
# Batch 9/17 - Generator Loss: -0.0027820318937301636, Discriminator Loss: 1.246052861213684
# Batch 10/17 - Generator Loss: -0.010089395567774773, Discriminator Loss: 1.2782316207885742
# Batch 11/17 - Generator Loss: -0.021847540512681007, Discriminator Loss: 1.2779667377471924
# Batch 12/17 - Generator Loss: -0.01822401024401188, Discriminator Loss: 1.2828774452209473
# Batch 13/17 - Generator Loss: -0.016715509817004204, Discriminator Loss: 1.2652599811553955
# Batch 14/17 - Generator Loss: -0.02405981533229351, Discriminator Loss: 1.2932958602905273
# Batch 15/17 - Generator Loss: -0.02312123216688633, Discriminator Loss: 1.2848814725875854
# Batch 16/17 - Generator Loss: -0.02773071825504303, Discriminator Loss: 1.3001761436462402
# Batch 17/17 - Generator Loss: -0.02746785245835781, Discriminator Loss: 1.2954005002975464
# Generator - Train: -0.02746785245835781, Val: -0.027548719197511673
# Discriminator - Train: 1.2954005002975464, Val: 1.310376524925232
# Epoch 6/50
# Batch 1/17 - Generator Loss: -0.03120001219213009, Discriminator Loss: 1.3015031814575195
# Batch 2/17 - Generator Loss: -0.02908896468579769, Discriminator Loss: 1.2931249141693115
# Batch 3/17 - Generator Loss: -0.03400607779622078, Discriminator Loss: 1.3126341104507446
# Batch 4/17 - Generator Loss: -0.038163356482982635, Discriminator Loss: 1.3242663145065308
# Batch 5/17 - Generator Loss: -0.04302164167165756, Discriminator Loss: 1.3194502592086792
# Batch 6/17 - Generator Loss: -0.051708970218896866, Discriminator Loss: 1.3413416147232056
# Batch 7/17 - Generator Loss: -0.050421420484781265, Discriminator Loss: 1.3299063444137573
# Batch 8/17 - Generator Loss: -0.05340046435594559, Discriminator Loss: 1.3445981740951538
# Batch 9/17 - Generator Loss: -0.0572829395532608, Discriminator Loss: 1.3552507162094116
# Batch 10/17 - Generator Loss: -0.055948711931705475, Discriminator Loss: 1.3389538526535034
# Batch 11/17 - Generator Loss: -0.05984560772776604, Discriminator Loss: 1.3483065366744995
# Batch 12/17 - Generator Loss: -0.06716158986091614, Discriminator Loss: 1.3542195558547974
# Batch 13/17 - Generator Loss: -0.07465658336877823, Discriminator Loss: 1.3614680767059326
# Batch 14/17 - Generator Loss: -0.07618109881877899, Discriminator Loss: 1.3653367757797241
# Batch 15/17 - Generator Loss: -0.07555915415287018, Discriminator Loss: 1.3679003715515137
# Batch 16/17 - Generator Loss: -0.07893244177103043, Discriminator Loss: 1.3760544061660767
# Batch 17/17 - Generator Loss: -0.08240742236375809, Discriminator Loss: 1.3753340244293213
# Generator - Train: -0.08240742236375809, Val: -0.08292488008737564
# Discriminator - Train: 1.3753340244293213, Val: 1.3775283098220825
# Epoch 7/50
# Batch 1/17 - Generator Loss: -0.08268137276172638, Discriminator Loss: 1.3783279657363892
# Batch 2/17 - Generator Loss: -0.08439876139163971, Discriminator Loss: 1.3820663690567017
# Batch 3/17 - Generator Loss: -0.08528710901737213, Discriminator Loss: 1.3810374736785889
# Batch 4/17 - Generator Loss: -0.08460929244756699, Discriminator Loss: 1.3769183158874512
# Batch 5/17 - Generator Loss: -0.08635084331035614, Discriminator Loss: 1.381705403327942
# Batch 6/17 - Generator Loss: -0.08758243918418884, Discriminator Loss: 1.383819818496704
# Batch 7/17 - Generator Loss: -0.08643278479576111, Discriminator Loss: 1.3814067840576172
# Batch 8/17 - Generator Loss: -0.08864539116621017, Discriminator Loss: 1.386411190032959
# Batch 9/17 - Generator Loss: -0.08999285846948624, Discriminator Loss: 1.3866873979568481
# Batch 10/17 - Generator Loss: -0.08966728299856186, Discriminator Loss: 1.385610580444336
# Batch 11/17 - Generator Loss: -0.08993759751319885, Discriminator Loss: 1.3862630128860474
# Batch 12/17 - Generator Loss: -0.09062898904085159, Discriminator Loss: 1.3868993520736694
# Batch 13/17 - Generator Loss: -0.09004759788513184, Discriminator Loss: 1.386572003364563
# Batch 14/17 - Generator Loss: -0.09122049063444138, Discriminator Loss: 1.3863648176193237
# Batch 15/17 - Generator Loss: -0.09162183851003647, Discriminator Loss: 1.3864967823028564
# Batch 16/17 - Generator Loss: -0.09116785228252411, Discriminator Loss: 1.386656641960144
# Batch 17/17 - Generator Loss: -0.09104399383068085, Discriminator Loss: 1.3866437673568726
# Generator - Train: -0.09104399383068085, Val: -0.09126860648393631
# Discriminator - Train: 1.3866437673568726, Val: 1.3866809606552124
# Epoch 8/50
# Batch 1/17 - Generator Loss: -0.09099315106868744, Discriminator Loss: 1.38664972782135
# Batch 2/17 - Generator Loss: -0.09265545010566711, Discriminator Loss: 1.3867186307907104
# Batch 3/17 - Generator Loss: -0.09316703677177429, Discriminator Loss: 1.3867043256759644
# Training stopped due to None loss value

# %%
gan.visualize_loss()

# %%
gan.visualize_generator_loss_components()

# %%
i=10

X = X_train[i]
z = X_train_z[i]
cX = cX_train[i]

a = gan.generate(X, z, cX)[0]

a.max(), a.min(), a.mean(), X_train[i].max(), X_train[i].min(), X_train[i].mean()
# Out:
# (0.995527, 0.05929015, 0.3586924, 1.0, 0.05883789, 0.3618848)

# %%
for i in range(2, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    gan.visualize_generated_image(X, z, cX)

# %%
for i in range(4, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    a = gan.generate(X, z, cX)

    from src.utils.optical_flow import draw_optical_flow

    draw_optical_flow(X[0], X[1])
    for i in range(len_generated_seq-1):
        draw_optical_flow(a[0][i], a[0][i+1])

# %%
from skimage import img_as_ubyte
import imageio
import numpy as np

def generate_gif(images, name):
    images = [img_as_ubyte(image) for image in images]
    images = [np.transpose(image, (1, 2, 0)) for image in images]
    imageio.mimsave(f'{name}.gif', images)

def generate_gif_gray(images, name):
    images = [img_as_ubyte(image) for image in images]
    imageio.mimsave(f'{name}.gif', images)

for i in range(0, X_val.shape[0]):
    X = X_val[i]
    z = X_val_z[i]
    cX = cX_val[i]

    images_list = gan.generate(X, z, cX)[0]

    images_list = np.concatenate((X, images_list), axis=0)

    # image to gray scale
    images_list_bw = np.zeros((images_list.shape[0], images_list.shape[2], images_list.shape[3]))
    for j in range(images_list.shape[0]):
        images_list_bw[j] = np.mean(images_list[j], axis=0)

    generate_gif_gray(images_list_bw, f'generated_images/generated_gif_no_obj/generated_sample_{i}')
