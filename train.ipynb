# %%
from src.wgan import WassersteinGAN

from src.utils.gan_dataloader import get_gan_dataset
from src.utils.make_discriminator import make_discriminator
from src.utils.make_generator import make_generator
#from notebooks.new_generator import make_generator

from tensorflow.keras.models import load_model

# %%
SAVE_TEST_RESULTS = False

# %% [markdown]
# ### Data

# %%
len_input_seq = 2
len_generated_seq = 2
X_train, X_val, X_test, X_train_z, X_val_z, X_test_z, cX_train, cX_val, cX_test = get_gan_dataset(len_input_seq)

# %%
def get_data():
    import pickle

    with open('data/new_data_no_obj.pkl', 'rb') as f:
        X_train, cX_train, X_train_z = pickle.load(f)

    # split the training set into training and validation
    n_sample_train = int(X_train.shape[0] * 0.8)

    X_train, X_val = X_train[:n_sample_train], X_train[n_sample_train:]
    cX_train, cX_val = cX_train[:n_sample_train], cX_train[n_sample_train:]
    X_train_z, X_val_z = X_train_z[:n_sample_train], X_train_z[n_sample_train:]

    len_input_seq = X_train.shape[1] # 6
    len_generated_seq = 6

    return X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq

#X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq = get_data()

# %% [markdown]
# ### Models

# %%
generator = make_generator(
    image_dim=[3, 64, 64],
    latent_dim=1280,
    conditions_dim=6,
    len_input_seq=len_input_seq,
    len_output_seq=len_generated_seq,
    n_filters=[16, 8, 8],
    kernel_size=[6, 3, 1],
    stride=[1, 1, 1],
    padding=['same', 'same', 'same'],
    hidden_dims=[128, 128],
    dropout=0.6,
    alpha=0.4,
)
#generator = load_model('generator_pretrained.h5')

discriminator = make_discriminator(
    input_dim=[3, 64, 64],
    len_input_seq=min(len_input_seq, len_generated_seq),
)

gan = WassersteinGAN(
    generator=generator,
    discriminator=discriminator,
    len_input_seq=len_input_seq,
    len_generated_seq=len_generated_seq,
    patience=5,
    learning_rate_generator=0.001,
    learning_rate_discriminator=0.05,
    n_critic=5,  # number of critic updates per generator update
    clip_value=0.01,
    discriminator_gradient_penalty_weight=0.02,
    generator_wloss_weight=0.5, # wasserstein loss weight
    generator_flow_loss_weight=0.3,
    generator_mse_weight=0.15,
    color_weight=0.05
)

# %% [markdown]
# ### Train

# %%
gan.train(
    X_train_z, X_train, cX_train, # noise, real images, conditions
    X_val_z, X_val, cX_val,
    epochs=20, batch_size=32
)
# Out:
# Epoch 1/20
# Batch 1/135 - Generator Loss: -0.0007498785853385925, Discriminator Loss: 1.238280177116394
# Batch 2/135 - Generator Loss: 0.024671092629432678, Discriminator Loss: 1.138384222984314
# Batch 3/135 - Generator Loss: 0.014379478991031647, Discriminator Loss: 1.1613490581512451
# Batch 4/135 - Generator Loss: 0.009540148079395294, Discriminator Loss: 1.1507985591888428
# Batch 5/135 - Generator Loss: -0.008075542747974396, Discriminator Loss: 1.1582114696502686
# Batch 6/135 - Generator Loss: -0.0699182078242302, Discriminator Loss: 1.2207876443862915
# Batch 7/135 - Generator Loss: -0.07321307063102722, Discriminator Loss: 1.2103692293167114
# Batch 8/135 - Generator Loss: -0.0796615406870842, Discriminator Loss: 1.2254825830459595
# Batch 9/135 - Generator Loss: -0.07953406125307083, Discriminator Loss: 1.2151836156845093
# Batch 10/135 - Generator Loss: -0.08497601002454758, Discriminator Loss: 1.2265584468841553
# Batch 11/135 - Generator Loss: -0.07804949581623077, Discriminator Loss: 1.2276768684387207
# Batch 12/135 - Generator Loss: -0.08246772736310959, Discriminator Loss: 1.219604730606079
# Batch 13/135 - Generator Loss: -0.08272718638181686, Discriminator Loss: 1.216623306274414
# Batch 14/135 - Generator Loss: -0.08187176287174225, Discriminator Loss: 1.2079570293426514
# Batch 15/135 - Generator Loss: -0.07925711572170258, Discriminator Loss: 1.217416524887085
# Batch 16/135 - Generator Loss: -0.09158395230770111, Discriminator Loss: 1.2325140237808228
# Batch 17/135 - Generator Loss: -0.08963555097579956, Discriminator Loss: 1.2460601329803467
# Batch 18/135 - Generator Loss: -0.08543602377176285, Discriminator Loss: 1.2268588542938232
# Batch 19/135 - Generator Loss: -0.08162091672420502, Discriminator Loss: 1.217002511024475
# Batch 20/135 - Generator Loss: -0.08418445289134979, Discriminator Loss: 1.2033071517944336
# Batch 21/135 - Generator Loss: -0.08926001191139221, Discriminator Loss: 1.2192049026489258
# Batch 22/135 - Generator Loss: -0.08775393664836884, Discriminator Loss: 1.2264511585235596
# Batch 23/135 - Generator Loss: -0.08010546863079071, Discriminator Loss: 1.217650294303894
# Batch 24/135 - Generator Loss: -0.08739055693149567, Discriminator Loss: 1.2237014770507812
# Batch 25/135 - Generator Loss: -0.08828754723072052, Discriminator Loss: 1.2141395807266235
# Batch 26/135 - Generator Loss: -0.09076477587223053, Discriminator Loss: 1.2240461111068726
# Batch 27/135 - Generator Loss: -0.09654586017131805, Discriminator Loss: 1.2339991331100464
# Batch 28/135 - Generator Loss: -0.09082195907831192, Discriminator Loss: 1.226691484451294
# Batch 29/135 - Generator Loss: -0.08604538440704346, Discriminator Loss: 1.2152276039123535
# Batch 30/135 - Generator Loss: -0.08999703079462051, Discriminator Loss: 1.2151570320129395
# Batch 31/135 - Generator Loss: -0.09409545361995697, Discriminator Loss: 1.2033414840698242
# Batch 32/135 - Generator Loss: -0.09425853937864304, Discriminator Loss: 1.2246953248977661
# Batch 33/135 - Generator Loss: -0.09635180234909058, Discriminator Loss: 1.2315254211425781
# Batch 34/135 - Generator Loss: -0.0923980101943016, Discriminator Loss: 1.2203028202056885
# Batch 35/135 - Generator Loss: -0.09762679785490036, Discriminator Loss: 1.2313759326934814
# Batch 36/135 - Generator Loss: -0.09501567482948303, Discriminator Loss: 1.228458285331726
# Batch 37/135 - Generator Loss: -0.09629383683204651, Discriminator Loss: 1.2283118963241577
# Batch 38/135 - Generator Loss: -0.1008710190653801, Discriminator Loss: 1.2455263137817383
# Batch 39/135 - Generator Loss: -0.10008374601602554, Discriminator Loss: 1.2245452404022217
# Batch 34/135 - Generator Loss: -0.14346152544021606, Discriminator Loss: 1.2803393602371216
# Batch 35/135 - Generator Loss: -0.15196727216243744, Discriminator Loss: 1.2792236804962158
# Batch 36/135 - Generator Loss: -0.1415095031261444, Discriminator Loss: 1.2682805061340332
# Batch 37/135 - Generator Loss: -0.15073762834072113, Discriminator Loss: 1.2710776329040527
# Batch 38/135 - Generator Loss: -0.15399327874183655, Discriminator Loss: 1.2674877643585205
# Batch 39/135 - Generator Loss: -0.15063366293907166, Discriminator Loss: 1.2774949073791504
# Batch 40/135 - Generator Loss: -0.14909645915031433, Discriminator Loss: 1.273568868637085
# Batch 41/135 - Generator Loss: -0.15561817586421967, Discriminator Loss: 1.293682336807251
# Batch 42/135 - Generator Loss: -0.15030741691589355, Discriminator Loss: 1.275399923324585
# Batch 43/135 - Generator Loss: -0.15480026602745056, Discriminator Loss: 1.2772424221038818
# Batch 44/135 - Generator Loss: -0.15058748424053192, Discriminator Loss: 1.2824347019195557
# Batch 45/135 - Generator Loss: -0.15752382576465607, Discriminator Loss: 1.2916545867919922
# Batch 46/135 - Generator Loss: -0.1477499008178711, Discriminator Loss: 1.2760525941848755
# Batch 47/135 - Generator Loss: -0.15817388892173767, Discriminator Loss: 1.289296269416809
# Batch 48/135 - Generator Loss: -0.15598325431346893, Discriminator Loss: 1.2749013900756836
# Batch 49/135 - Generator Loss: -0.15619662404060364, Discriminator Loss: 1.2836533784866333
# Batch 50/135 - Generator Loss: -0.15440285205841064, Discriminator Loss: 1.276630163192749
# Batch 51/135 - Generator Loss: -0.15652041137218475, Discriminator Loss: 1.2862589359283447
# Batch 52/135 - Generator Loss: -0.15428978204727173, Discriminator Loss: 1.2861666679382324
# Batch 53/135 - Generator Loss: -0.16049271821975708, Discriminator Loss: 1.2857658863067627
# Batch 54/135 - Generator Loss: -0.15832579135894775, Discriminator Loss: 1.2866106033325195
# Batch 55/135 - Generator Loss: -0.15534725785255432, Discriminator Loss: 1.2747222185134888
# Batch 56/135 - Generator Loss: -0.15873253345489502, Discriminator Loss: 1.2907078266143799
# Batch 57/135 - Generator Loss: -0.15951503813266754, Discriminator Loss: 1.2955381870269775
# Batch 58/135 - Generator Loss: -0.1644965261220932, Discriminator Loss: 1.2913185358047485
# Batch 59/135 - Generator Loss: -0.160383403301239, Discriminator Loss: 1.3046526908874512
# Batch 60/135 - Generator Loss: -0.1606302112340927, Discriminator Loss: 1.2963565587997437
# Batch 61/135 - Generator Loss: -0.16504818201065063, Discriminator Loss: 1.2908732891082764
# Batch 62/135 - Generator Loss: -0.1555997133255005, Discriminator Loss: 1.2871615886688232
# Batch 63/135 - Generator Loss: -0.15847128629684448, Discriminator Loss: 1.3051540851593018
# Batch 64/135 - Generator Loss: -0.15074166655540466, Discriminator Loss: 1.2926266193389893
# Batch 65/135 - Generator Loss: -0.15885424613952637, Discriminator Loss: 1.30080246925354
# Batch 132/135 - Generator Loss: -0.19558605551719666, Discriminator Loss: 1.352057695388794
# Batch 133/135 - Generator Loss: -0.19230560958385468, Discriminator Loss: 1.3526544570922852
# Batch 134/135 - Generator Loss: -0.20276682078838348, Discriminator Loss: 1.364796757698059
# Batch 135/135 - Generator Loss: -0.189579039812088, Discriminator Loss: 1.3443012237548828
# Generator - Train: -0.189579039812088, Val: -0.19186556339263916
# Discriminator - Train: 1.3443012237548828, Val: 1.3529915809631348
# Epoch 3/20
# Batch 1/135 - Generator Loss: -0.1934995800256729, Discriminator Loss: 1.3531628847122192
# Batch 2/135 - Generator Loss: -0.19391146302223206, Discriminator Loss: 1.3492622375488281
# Batch 3/135 - Generator Loss: -0.20081356167793274, Discriminator Loss: 1.3607475757598877
# Batch 4/135 - Generator Loss: -0.1965433657169342, Discriminator Loss: 1.3522897958755493
# Batch 5/135 - Generator Loss: -0.1985013484954834, Discriminator Loss: 1.3508673906326294
# Batch 6/135 - Generator Loss: -0.19976623356342316, Discriminator Loss: 1.3573766946792603
# Batch 7/135 - Generator Loss: -0.19951631128787994, Discriminator Loss: 1.3581922054290771
# Batch 8/135 - Generator Loss: -0.20038668811321259, Discriminator Loss: 1.3652223348617554
# Batch 9/135 - Generator Loss: -0.2083980292081833, Discriminator Loss: 1.3724950551986694
# Batch 10/135 - Generator Loss: -0.19674231112003326, Discriminator Loss: 1.3545128107070923
# Batch 11/135 - Generator Loss: -0.20034456253051758, Discriminator Loss: 1.35507071018219
# Batch 12/135 - Generator Loss: -0.19470913708209991, Discriminator Loss: 1.356297254562378
# Batch 13/135 - Generator Loss: -0.20198705792427063, Discriminator Loss: 1.3580442667007446
# Batch 14/135 - Generator Loss: -0.2014637589454651, Discriminator Loss: 1.3618100881576538
# Batch 15/135 - Generator Loss: -0.20499379932880402, Discriminator Loss: 1.3650647401809692
# Batch 16/135 - Generator Loss: -0.2026425302028656, Discriminator Loss: 1.3625808954238892
# Batch 17/135 - Generator Loss: -0.20191991329193115, Discriminator Loss: 1.3584208488464355
# Batch 18/135 - Generator Loss: -0.19839392602443695, Discriminator Loss: 1.3624417781829834
# Batch 19/135 - Generator Loss: -0.2001120150089264, Discriminator Loss: 1.3569573163986206
# Batch 20/135 - Generator Loss: -0.19589708745479584, Discriminator Loss: 1.352475643157959
# Batch 21/135 - Generator Loss: -0.19818225502967834, Discriminator Loss: 1.3545968532562256
# Batch 22/135 - Generator Loss: -0.20155967772006989, Discriminator Loss: 1.3588308095932007
# Batch 23/135 - Generator Loss: -0.20413602888584137, Discriminator Loss: 1.3619462251663208
# Batch 24/135 - Generator Loss: -0.20226241648197174, Discriminator Loss: 1.3585206270217896
# Batch 25/135 - Generator Loss: -0.20119322836399078, Discriminator Loss: 1.3591886758804321
# Batch 26/135 - Generator Loss: -0.20248736441135406, Discriminator Loss: 1.3610693216323853
# Batch 27/135 - Generator Loss: -0.20719720423221588, Discriminator Loss: 1.3636375665664673
# Batch 60/135 - Generator Loss: -0.2187562733888626, Discriminator Loss: 1.3768912553787231
# Batch 61/135 - Generator Loss: -0.2173299491405487, Discriminator Loss: 1.3774319887161255
# Batch 62/135 - Generator Loss: -0.22004063427448273, Discriminator Loss: 1.3794878721237183
# Batch 63/135 - Generator Loss: -0.21696224808692932, Discriminator Loss: 1.3769029378890991
# Batch 64/135 - Generator Loss: -0.21832968294620514, Discriminator Loss: 1.3755078315734863
# Batch 65/135 - Generator Loss: -0.22061200439929962, Discriminator Loss: 1.379164695739746
# Batch 66/135 - Generator Loss: -0.22071602940559387, Discriminator Loss: 1.3804916143417358
# Batch 67/135 - Generator Loss: -0.22104883193969727, Discriminator Loss: 1.3809484243392944
# Batch 68/135 - Generator Loss: -0.21799114346504211, Discriminator Loss: 1.376461386680603
# Batch 69/135 - Generator Loss: -0.2187911421060562, Discriminator Loss: 1.376219391822815
# Batch 70/135 - Generator Loss: -0.2194635272026062, Discriminator Loss: 1.3780006170272827
# Batch 71/135 - Generator Loss: -0.22010059654712677, Discriminator Loss: 1.3784161806106567
# Batch 72/135 - Generator Loss: -0.22236445546150208, Discriminator Loss: 1.3809303045272827

# %%
gan.visualize_loss()

# %%
gan.visualize_generator_loss_components()

# %%
i=10

X = X_train[i]
z = X_train_z[i]
cX = cX_train[i]

a = gan.generate(X, z, cX)[0]

a.max(), a.min(), a.mean(), X_train[i].max(), X_train[i].min(), X_train[i].mean()
# Out:
# (0.9984951, 0.20637871, 0.40339804, 1.0, 0.05883789, 0.3612682)

# %%
for i in range(2, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    gan.visualize_generated_image(X, z, cX)

# %%
for i in range(4, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    a = gan.generate(X, z, cX)

    from src.utils.optical_flow import draw_optical_flow

    draw_optical_flow(X[0], X[1])
    for i in range(len_generated_seq-1):
        draw_optical_flow(a[0][i], a[0][i+1])

# %%
from skimage import img_as_ubyte
import imageio
import numpy as np

def generate_gif(images, name):
    images = [img_as_ubyte(image) for image in images]
    images = [np.transpose(image, (1, 2, 0)) for image in images]
    imageio.mimsave(f'{name}.gif', images)

def generate_gif_gray(images, name):
    images = [img_as_ubyte(image) for image in images]
    imageio.mimsave(f'{name}.gif', images)

for i in range(0, 30, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    images_list = gan.generate(X, z, cX)[0]

    images_list = np.concatenate((X, images_list), axis=0)

    # image to gray scale
    images_list_bw = np.zeros((images_list.shape[0], images_list.shape[2], images_list.shape[3]))
    for j in range(images_list.shape[0]):
        images_list_bw[j] = np.mean(images_list[j], axis=0)

    generate_gif_gray(images_list_bw, f'generated_images/generated_gif/generated_sample_{i}')

# %%
if SAVE_TEST_RESULTS:
    for i, (X, z, cX) in enumerate(zip(X_test, X_test_z, cX_test)):
        gan.save_generated_image(X, z, cX, path=f'generated_images/wgan_test/generated_image_{i}.png')
