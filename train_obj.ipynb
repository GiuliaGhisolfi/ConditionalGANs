# %%
from src.wgan import WassersteinGAN

from src.utils.make_discriminator import make_discriminator
from src.utils.make_generator import make_generator
# Out:
# c:\Users\giuli\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Data

# %%
def get_data():
    import pickle

    with open('data/new_data_obj.pkl', 'rb') as f:
        X_train, cX_train, X_train_z = pickle.load(f)

    # split the training set into training and validation
    n_sample_train = int(X_train.shape[0] * 0.8)

    X_train, X_val = X_train[:n_sample_train], X_train[n_sample_train:]
    cX_train, cX_val = cX_train[:n_sample_train], cX_train[n_sample_train:]
    X_train_z, X_val_z = X_train_z[:n_sample_train], X_train_z[n_sample_train:]

    len_input_seq = X_train.shape[1] # 6
    len_generated_seq = 2

    return X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq

X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq = get_data()

# %% [markdown]
# ### Models

# %%
generator = make_generator(
    image_dim=[3, 64, 64],
    latent_dim=1280,
    conditions_dim=6,
    len_input_seq=len_input_seq,
    len_output_seq=len_generated_seq,
    n_filters=[16, 8, 8],
    kernel_size=[5, 3, 1],
    stride=[1, 1, 1],
    padding=['same', 'same', 'same'],
    hidden_dims=[128, 128],
)

discriminator = make_discriminator(
    input_dim=[3, 64, 64],
    len_input_seq=min(len_input_seq, len_generated_seq),
)

gan = WassersteinGAN(
    generator=generator,
    discriminator=discriminator,
    len_input_seq=len_input_seq,
    len_generated_seq=len_generated_seq,
    patience=5,
    learning_rate_generator=0.01,
    learning_rate_discriminator=0.01,
    n_critic=5,  # number of critic updates per generator update
    clip_value=0.01,
    discriminator_gradient_penalty_weight=0.02,
    generator_wloss_weight=0.5,
    generator_flow_loss_weight=0.3,
    generator_mse_weight=0.15,
    color_weight=0.05,
    save_path = 'wgan_train_obj'
)

# %% [markdown]
# ### Train

# %%
gan.train(
    X_train_z, X_train, cX_train, # noise, real images, conditions
    X_val_z, X_val, cX_val,
    epochs=50, batch_size=128
)
# Out:
# Epoch 1/50
# Batch 1/4 - Generator Loss: 0.04890795797109604, Discriminator Loss: 1.3224492073059082
# Batch 2/4 - Generator Loss: 0.06921565532684326, Discriminator Loss: 0.9223055243492126
# Batch 3/4 - Generator Loss: -0.012559756636619568, Discriminator Loss: 0.9854058623313904
# Batch 4/4 - Generator Loss: -0.04379064962267876, Discriminator Loss: 1.0146455764770508
# Generator - Train: -0.04379064962267876, Val: -0.05488605424761772
# Discriminator - Train: 1.0146455764770508, Val: 1.0158179998397827
# Epoch 2/50
# Batch 1/4 - Generator Loss: -0.035966940224170685, Discriminator Loss: 1.0177303552627563
# Batch 2/4 - Generator Loss: -0.06424891203641891, Discriminator Loss: 1.030677080154419
# Batch 3/4 - Generator Loss: -0.05228324979543686, Discriminator Loss: 1.0341670513153076
# Batch 4/4 - Generator Loss: -0.07146146893501282, Discriminator Loss: 1.048276662826538
# Generator - Train: -0.07146146893501282, Val: -0.0763091892004013
# Discriminator - Train: 1.048276662826538, Val: 1.042701005935669
# Epoch 3/50
# Batch 1/4 - Generator Loss: -0.06129539757966995, Discriminator Loss: 1.0424795150756836
# Batch 2/4 - Generator Loss: -0.07940062880516052, Discriminator Loss: 1.0454374551773071
# Batch 3/4 - Generator Loss: -0.07200279831886292, Discriminator Loss: 1.0549484491348267
# Batch 4/4 - Generator Loss: -0.09101651608943939, Discriminator Loss: 1.0635371208190918
# Generator - Train: -0.09101651608943939, Val: -0.09314810484647751
# Discriminator - Train: 1.0635371208190918, Val: 1.0677859783172607
# Epoch 4/50
# Batch 1/4 - Generator Loss: -0.0827912837266922, Discriminator Loss: 1.072394847869873
# Batch 2/4 - Generator Loss: -0.09688130021095276, Discriminator Loss: 1.0828022956848145
# Batch 3/4 - Generator Loss: -0.08639195561408997, Discriminator Loss: 1.0764093399047852
# Batch 4/4 - Generator Loss: -0.10385312139987946, Discriminator Loss: 1.0854012966156006
# Generator - Train: -0.10385312139987946, Val: -0.10647733509540558
# Discriminator - Train: 1.0854012966156006, Val: 1.088552474975586
# Epoch 5/50
# Batch 1/4 - Generator Loss: -0.096437469124794, Discriminator Loss: 1.0866050720214844
# Batch 2/4 - Generator Loss: -0.1119263768196106, Discriminator Loss: 1.1064252853393555
# Batch 3/4 - Generator Loss: -0.10121630132198334, Discriminator Loss: 1.1051075458526611
# Batch 4/4 - Generator Loss: -0.11596368253231049, Discriminator Loss: 1.114726185798645
# Generator - Train: -0.11596368253231049, Val: -0.11755054444074631
# Discriminator - Train: 1.114726185798645, Val: 1.1068229675292969
# Epoch 6/50
# Batch 1/4 - Generator Loss: -0.10630586743354797, Discriminator Loss: 1.106154441833496
# Batch 2/4 - Generator Loss: -0.12214387208223343, Discriminator Loss: 1.127248764038086
# Batch 3/4 - Generator Loss: -0.11181876063346863, Discriminator Loss: 1.1168893575668335
# Batch 4/4 - Generator Loss: -0.12472902238368988, Discriminator Loss: 1.1517155170440674
# Generator - Train: -0.12472902238368988, Val: -0.12706828117370605
# Discriminator - Train: 1.1517155170440674, Val: 1.1244288682937622
# Epoch 7/50
# Batch 1/4 - Generator Loss: -0.11634024977684021, Discriminator Loss: 1.1323411464691162
# Batch 2/4 - Generator Loss: -0.13260838389396667, Discriminator Loss: 1.1409568786621094
# Batch 3/4 - Generator Loss: -0.11936278641223907, Discriminator Loss: 1.142448902130127
# Batch 4/4 - Generator Loss: -0.13507896661758423, Discriminator Loss: 1.1533336639404297
# Generator - Train: -0.13507896661758423, Val: -0.1361742615699768
# Discriminator - Train: 1.1533336639404297, Val: 1.1433433294296265
# Epoch 8/50
# Batch 1/4 - Generator Loss: -0.12209315598011017, Discriminator Loss: 1.1435942649841309
# Batch 2/4 - Generator Loss: -0.13799579441547394, Discriminator Loss: 1.1720590591430664
# Batch 3/4 - Generator Loss: -0.13084253668785095, Discriminator Loss: 1.1501766443252563
# Batch 4/4 - Generator Loss: -0.14205673336982727, Discriminator Loss: 1.1843810081481934
# Generator - Train: -0.14205673336982727, Val: -0.14446350932121277
# Discriminator - Train: 1.1843810081481934, Val: 1.1605961322784424
# Epoch 9/50
# Batch 1/4 - Generator Loss: -0.1302180290222168, Discriminator Loss: 1.1612517833709717
# Batch 2/4 - Generator Loss: -0.14711883664131165, Discriminator Loss: 1.1845662593841553
# Batch 3/4 - Generator Loss: -0.13151957094669342, Discriminator Loss: 1.1634840965270996
# Batch 4/4 - Generator Loss: -0.14901040494441986, Discriminator Loss: 1.188618779182434
# Generator - Train: -0.14901040494441986, Val: -0.1509428322315216
# Discriminator - Train: 1.188618779182434, Val: 1.1735782623291016
# Epoch 10/50
# Batch 1/4 - Generator Loss: -0.13709481060504913, Discriminator Loss: 1.1703174114227295
# Batch 2/4 - Generator Loss: -0.15272937715053558, Discriminator Loss: 1.1971617937088013
# Batch 3/4 - Generator Loss: -0.1427982598543167, Discriminator Loss: 1.1837102174758911
# Batch 4/4 - Generator Loss: -0.15729005634784698, Discriminator Loss: 1.2128996849060059
# Generator - Train: -0.15729005634784698, Val: -0.1592807173728943
# Discriminator - Train: 1.2128996849060059, Val: 1.1928412914276123
# Epoch 11/50
# Batch 1/4 - Generator Loss: -0.1474282145500183, Discriminator Loss: 1.2002735137939453
# Batch 2/4 - Generator Loss: -0.1623898297548294, Discriminator Loss: 1.2132186889648438
# Batch 3/4 - Generator Loss: -0.14845873415470123, Discriminator Loss: 1.198166847229004
# Batch 4/4 - Generator Loss: -0.16627638041973114, Discriminator Loss: 1.2303056716918945
# Generator - Train: -0.16627638041973114, Val: -0.16815318167209625
# Discriminator - Train: 1.2303056716918945, Val: 1.2131767272949219
# Epoch 12/50
# Batch 1/4 - Generator Loss: -0.1531863808631897, Discriminator Loss: 1.214167594909668
# Batch 2/4 - Generator Loss: -0.17035973072052002, Discriminator Loss: 1.2438468933105469
# Batch 3/4 - Generator Loss: -0.15906399488449097, Discriminator Loss: 1.2206759452819824
# Batch 4/4 - Generator Loss: -0.16961506009101868, Discriminator Loss: 1.2309174537658691
# Generator - Train: -0.16961506009101868, Val: -0.1712864339351654
# Discriminator - Train: 1.2309174537658691, Val: 1.2341759204864502
# Epoch 13/50
# Batch 1/4 - Generator Loss: -0.1716034859418869, Discriminator Loss: 1.229940414428711
# Batch 2/4 - Generator Loss: -0.17522501945495605, Discriminator Loss: 1.24136221408844
# Batch 3/4 - Generator Loss: -0.17657142877578735, Discriminator Loss: 1.2492293119430542
# Batch 4/4 - Generator Loss: -0.18019476532936096, Discriminator Loss: 1.254697561264038
# Generator - Train: -0.18019476532936096, Val: -0.18082450330257416
# Discriminator - Train: 1.254697561264038, Val: 1.261110544204712
# Epoch 14/50
# Batch 1/4 - Generator Loss: -0.18137939274311066, Discriminator Loss: 1.25885009765625
# Batch 2/4 - Generator Loss: -0.18527212738990784, Discriminator Loss: 1.262369990348816
# Batch 3/4 - Generator Loss: -0.1882867068052292, Discriminator Loss: 1.2682056427001953
# Batch 4/4 - Generator Loss: -0.19013063609600067, Discriminator Loss: 1.2797197103500366
# Generator - Train: -0.19013063609600067, Val: -0.19280357658863068
# Discriminator - Train: 1.2797197103500366, Val: 1.285930871963501
# Epoch 15/50
# Batch 1/4 - Generator Loss: -0.19359271228313446, Discriminator Loss: 1.2881569862365723
# Batch 2/4 - Generator Loss: -0.19457733631134033, Discriminator Loss: 1.2918975353240967
# Batch 3/4 - Generator Loss: -0.19598811864852905, Discriminator Loss: 1.3012226819992065
# Batch 4/4 - Generator Loss: -0.2010578066110611, Discriminator Loss: 1.3086774349212646
# Generator - Train: -0.2010578066110611, Val: -0.20239706337451935
# Discriminator - Train: 1.3086774349212646, Val: 1.314911961555481
# Epoch 16/50
# Batch 1/4 - Generator Loss: -0.2030716985464096, Discriminator Loss: 1.3165192604064941
# Batch 2/4 - Generator Loss: -0.2084483802318573, Discriminator Loss: 1.3218531608581543
# Batch 3/4 - Generator Loss: -0.20376227796077728, Discriminator Loss: 1.330140471458435
# Batch 4/4 - Generator Loss: -0.21002119779586792, Discriminator Loss: 1.3336586952209473
# Generator - Train: -0.21002119779586792, Val: -0.21190626919269562
# Discriminator - Train: 1.3336586952209473, Val: 1.3436611890792847
# Epoch 17/50
# Batch 1/4 - Generator Loss: -0.20858947932720184, Discriminator Loss: 1.3425824642181396
# Batch 2/4 - Generator Loss: -0.21590648591518402, Discriminator Loss: 1.3573195934295654
# Batch 3/4 - Generator Loss: -0.22112250328063965, Discriminator Loss: 1.3667789697647095
# Batch 4/4 - Generator Loss: -0.22717590630054474, Discriminator Loss: 1.369035243988037
# Generator - Train: -0.22717590630054474, Val: -0.2273879051208496
# Discriminator - Train: 1.369035243988037, Val: 1.3690792322158813
# Epoch 18/50
# Batch 1/4 - Generator Loss: -0.22687263786792755, Discriminator Loss: 1.3697936534881592
# Batch 2/4 - Generator Loss: -0.22692269086837769, Discriminator Loss: 1.374540090560913
# Batch 3/4 - Generator Loss: -0.23202070593833923, Discriminator Loss: 1.3759574890136719
# Batch 4/4 - Generator Loss: -0.2343713492155075, Discriminator Loss: 1.3780021667480469
# Generator - Train: -0.2343713492155075, Val: -0.23403766751289368
# Discriminator - Train: 1.3780021667480469, Val: 1.3788245916366577
# Epoch 19/50
# Batch 1/4 - Generator Loss: -0.23539063334465027, Discriminator Loss: 1.3800716400146484
# Batch 2/4 - Generator Loss: -0.23709622025489807, Discriminator Loss: 1.3803894519805908
# Batch 3/4 - Generator Loss: -0.23509441316127777, Discriminator Loss: 1.3805668354034424
# Batch 4/4 - Generator Loss: -0.23820294439792633, Discriminator Loss: 1.3813194036483765
# Generator - Train: -0.23820294439792633, Val: -0.23796232044696808
# Discriminator - Train: 1.3813194036483765, Val: 1.3813124895095825
# Epoch 20/50
# Batch 1/4 - Generator Loss: -0.23837962746620178, Discriminator Loss: 1.3817907571792603
# Batch 2/4 - Generator Loss: -0.23895058035850525, Discriminator Loss: 1.3818567991256714
# Batch 3/4 - Generator Loss: -0.24005836248397827, Discriminator Loss: 1.3825818300247192
# Batch 4/4 - Generator Loss: -0.23930467665195465, Discriminator Loss: 1.382337212562561
# Generator - Train: -0.23930467665195465, Val: -0.23919835686683655
# Discriminator - Train: 1.382337212562561, Val: 1.3837040662765503
# Epoch 21/50
# Batch 1/4 - Generator Loss: -0.23975400626659393, Discriminator Loss: 1.3832629919052124
# Batch 2/4 - Generator Loss: -0.24104362726211548, Discriminator Loss: 1.3833529949188232
# Batch 3/4 - Generator Loss: -0.24246035516262054, Discriminator Loss: 1.3852840662002563
# Batch 4/4 - Generator Loss: -0.24198055267333984, Discriminator Loss: 1.3851388692855835
# Generator - Train: -0.24198055267333984, Val: -0.24173636734485626
# Discriminator - Train: 1.3851388692855835, Val: 1.3847484588623047
# Epoch 22/50
# Batch 1/4 - Generator Loss: -0.2428552210330963, Discriminator Loss: 1.3853753805160522
# Batch 2/4 - Generator Loss: -0.24319994449615479, Discriminator Loss: 1.3856562376022339
# Batch 3/4 - Generator Loss: -0.2439761459827423, Discriminator Loss: 1.386214017868042
# Batch 4/4 - Generator Loss: -0.24427062273025513, Discriminator Loss: 1.3861899375915527
# Generator - Train: -0.24427062273025513, Val: -0.24411210417747498
# Discriminator - Train: 1.3861899375915527, Val: 1.3859769105911255
# Epoch 23/50
# Batch 1/4 - Generator Loss: -0.2439487725496292, Discriminator Loss: 1.385956883430481
# Batch 2/4 - Generator Loss: -0.24420131742954254, Discriminator Loss: 1.3860846757888794
# Batch 3/4 - Generator Loss: -0.24405911564826965, Discriminator Loss: 1.3857663869857788
# Batch 4/4 - Generator Loss: -0.24414929747581482, Discriminator Loss: 1.3857084512710571
# Generator - Train: -0.24414929747581482, Val: -0.24389538168907166
# Discriminator - Train: 1.3857084512710571, Val: 1.3861364126205444
# Epoch 24/50
# Batch 1/4 - Generator Loss: -0.24451877176761627, Discriminator Loss: 1.38646399974823
# Batch 2/4 - Generator Loss: -0.2446957528591156, Discriminator Loss: 1.3862777948379517
# Batch 3/4 - Generator Loss: -0.24472787976264954, Discriminator Loss: 1.3863776922225952
# Batch 4/4 - Generator Loss: -0.2457856833934784, Discriminator Loss: 1.3867427110671997
# Generator - Train: -0.2457856833934784, Val: -0.2454497218132019
# Discriminator - Train: 1.3867427110671997, Val: 1.3865448236465454
# Epoch 25/50
# Batch 1/4 - Generator Loss: -0.24592003226280212, Discriminator Loss: 1.386017918586731
# Batch 2/4 - Generator Loss: -0.24537985026836395, Discriminator Loss: 1.3866040706634521
# Batch 3/4 - Generator Loss: -0.24546091258525848, Discriminator Loss: 1.3864798545837402
# Batch 4/4 - Generator Loss: -0.24570414423942566, Discriminator Loss: 1.3866982460021973
# Generator - Train: -0.24570414423942566, Val: -0.24534176290035248
# Discriminator - Train: 1.3866982460021973, Val: 1.3866517543792725
# Epoch 26/50
# Batch 1/4 - Generator Loss: -0.2453816831111908, Discriminator Loss: 1.3866647481918335
# Batch 2/4 - Generator Loss: -0.24546141922473907, Discriminator Loss: 1.386684536933899
# Batch 3/4 - Generator Loss: -0.24565830826759338, Discriminator Loss: 1.3866853713989258
# Batch 4/4 - Generator Loss: -0.2454240620136261, Discriminator Loss: 1.386668086051941
# Generator - Train: -0.2454240620136261, Val: -0.245021790266037
# Discriminator - Train: 1.386668086051941, Val: 1.386686086654663
# Epoch 27/50
# Batch 1/4 - Generator Loss: -0.2451673448085785, Discriminator Loss: 1.3866201639175415
# Batch 2/4 - Generator Loss: -0.24566808342933655, Discriminator Loss: 1.3866995573043823
# Batch 3/4 - Generator Loss: -0.24583275616168976, Discriminator Loss: 1.3866949081420898
# Batch 4/4 - Generator Loss: -0.24597468972206116, Discriminator Loss: 1.3866969347000122
# Generator - Train: -0.24597468972206116, Val: -0.24555446207523346
# Discriminator - Train: 1.3866969347000122, Val: 1.386694073677063
# Epoch 28/50
# Batch 1/4 - Generator Loss: 1.0041781663894653, Discriminator Loss: 2.0399999618530273
# Batch 2/4 - Generator Loss: 1.4005481004714966, Discriminator Loss: 2.0399999618530273
# Batch 3/4 - Generator Loss: 1.4005330801010132, Discriminator Loss: 2.0399999618530273
# Batch 4/4 - Generator Loss: 1.4005554914474487, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.4005554914474487, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Epoch 29/50
# Batch 1/4 - Generator Loss: 1.4005309343338013, Discriminator Loss: 2.0399999618530273
# Batch 2/4 - Generator Loss: 1.400546669960022, Discriminator Loss: 2.0399999618530273
# Batch 3/4 - Generator Loss: 1.4005693197250366, Discriminator Loss: 2.0399999618530273
# Batch 4/4 - Generator Loss: 1.400560975074768, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.400560975074768, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Epoch 30/50
# Batch 1/4 - Generator Loss: 1.4005519151687622, Discriminator Loss: 2.0399999618530273
# Batch 2/4 - Generator Loss: 1.4005120992660522, Discriminator Loss: 2.0399999618530273
# Batch 3/4 - Generator Loss: 1.4005740880966187, Discriminator Loss: 2.0399999618530273
# Batch 4/4 - Generator Loss: 1.4005495309829712, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.4005495309829712, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Epoch 31/50
# Batch 1/4 - Generator Loss: 1.4005483388900757, Discriminator Loss: 2.0399999618530273
# Batch 2/4 - Generator Loss: 1.40054190158844, Discriminator Loss: 2.0399999618530273
# Batch 3/4 - Generator Loss: 1.4005218744277954, Discriminator Loss: 2.0399999618530273
# Batch 4/4 - Generator Loss: 1.4006048440933228, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.4006048440933228, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Epoch 32/50
# Batch 1/4 - Generator Loss: 1.4005359411239624, Discriminator Loss: 2.0399999618530273
# Batch 2/4 - Generator Loss: 1.4005924463272095, Discriminator Loss: 2.0399999618530273
# Batch 3/4 - Generator Loss: 1.400572419166565, Discriminator Loss: 2.0399999618530273
# Batch 4/4 - Generator Loss: 1.400506854057312, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.400506854057312, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Early stopping at epoch 32. No improvement for 5 consecutive epochs.
# Best validation loss: -0.24555446207523346 at epoch 27

# %%
gan.visualize_loss()

# %%
gan.visualize_generator_loss_components()

# %%
i=10

X = X_train[i]
z = X_train_z[i]
cX = cX_train[i]

a = gan.generate(X, z, cX)[0]

a.max(), a.min(), a.mean(), X_train[i].max(), X_train[i].min(), X_train[i].mean()
# Out:
# (0.9987138, 0.16564475, 0.35243943, 1.0, 0.0, 0.36163604)

# %%
for i in range(2, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    gan.visualize_generated_image(X, z, cX)

# %%
for i in range(4, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    a = gan.generate(X, z, cX)

    from src.utils.optical_flow import draw_optical_flow

    draw_optical_flow(X[0], X[1])
    for i in range(len_generated_seq-1):
        draw_optical_flow(a[0][i], a[0][i+1])

# %%
from skimage import img_as_ubyte
import imageio
import numpy as np

def generate_gif(images, name):
    images = [img_as_ubyte(image) for image in images]
    images = [np.transpose(image, (1, 2, 0)) for image in images]
    imageio.mimsave(f'{name}.gif', images)

def generate_gif_gray(images, name):
    images = [img_as_ubyte(image) for image in images]
    imageio.mimsave(f'{name}.gif', images)

for i in range(0, X_val.shape[0]):
    X = X_val[i]
    z = X_val_z[i]
    cX = cX_val[i]

    images_list = gan.generate(X, z, cX)[0]

    images_list = np.concatenate((X, images_list), axis=0)

    # image to gray scale
    images_list_bw = np.zeros((images_list.shape[0], images_list.shape[2], images_list.shape[3]))
    for j in range(images_list.shape[0]):
        images_list_bw[j] = np.mean(images_list[j], axis=0)

    generate_gif_gray(images_list_bw, f'generated_images/generated_gif_obj/generated_sample_{i}')
