# %%
from src.wgan import WassersteinGAN

from src.utils.make_discriminator import make_discriminator
from src.utils.make_generator import make_generator

# %% [markdown]
# ### Data

# %%
def get_data():
    import pickle

    with open('data/new_data_obj.pkl', 'rb') as f:
        X_train, cX_train, X_train_z = pickle.load(f)

    # split the training set into training and validation
    n_sample_train = int(X_train.shape[0] * 0.8)

    X_train, X_val = X_train[:n_sample_train], X_train[n_sample_train:]
    cX_train, cX_val = cX_train[:n_sample_train], cX_train[n_sample_train:]
    X_train_z, X_val_z = X_train_z[:n_sample_train], X_train_z[n_sample_train:]

    len_input_seq = X_train.shape[1] # 6
    len_generated_seq = 2

    return X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq

X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq = get_data()

# %% [markdown]
# ### Models

# %%
generator = make_generator(
    image_dim=[3, 64, 64],
    latent_dim=1280,
    conditions_dim=6,
    len_input_seq=len_input_seq,
    len_output_seq=len_generated_seq,
    n_filters=[16, 8, 8, 16],
    kernel_size=[8, 5, 3, 1],
    stride=[3, 1, 1, 1],
    padding=['same', 'same', 'same', 'same'],
    hidden_dims=[128, 128],
)

discriminator = make_discriminator(
    input_dim=[3, 64, 64],
    len_input_seq=min(len_input_seq, len_generated_seq),
)

gan = WassersteinGAN(
    generator=generator,
    discriminator=discriminator,
    len_input_seq=len_input_seq,
    len_generated_seq=len_generated_seq,
    patience=3,
    learning_rate_generator=0.01,
    learning_rate_discriminator=0.01,
    n_critic=5,  # number of critic updates per generator update
    clip_value=0.01,
    discriminator_gradient_penalty_weight=0.02,
    generator_wloss_weight=0.5,
    generator_flow_loss_weight=0.3,
    generator_mse_weight=0.15,
    color_weight=0.05,
    save_path = 'wgan_train_obj'
)

# %% [markdown]
# ### Train

# %%
gan.train(
    X_train_z, X_train, cX_train, # noise, real images, conditions
    X_val_z, X_val, cX_val,
    epochs=20, batch_size=32
)
# Out:
# Epoch 1/20
# Batch 1/17 - Generator Loss: 0.04185883700847626, Discriminator Loss: 1.295737624168396
# Batch 2/17 - Generator Loss: 0.07925630360841751, Discriminator Loss: 0.9726791381835938
# Batch 3/17 - Generator Loss: 0.08812335878610611, Discriminator Loss: 0.8899766206741333
# Batch 4/17 - Generator Loss: 0.07644529640674591, Discriminator Loss: 0.9047076106071472
# Batch 5/17 - Generator Loss: 0.07888268679380417, Discriminator Loss: 0.928766131401062
# Batch 6/17 - Generator Loss: 0.07979302108287811, Discriminator Loss: 0.8883182406425476
# Batch 7/17 - Generator Loss: 0.09012196213006973, Discriminator Loss: 0.9066053628921509
# Batch 8/17 - Generator Loss: 0.06909714639186859, Discriminator Loss: 0.9026452302932739
# Batch 9/17 - Generator Loss: 0.07838618010282516, Discriminator Loss: 0.9310271143913269
# Batch 10/17 - Generator Loss: 0.07904542982578278, Discriminator Loss: 0.9055339694023132
# Batch 11/17 - Generator Loss: 0.07854332774877548, Discriminator Loss: 0.9058319926261902
# Batch 12/17 - Generator Loss: 0.05849535018205643, Discriminator Loss: 0.9077317714691162
# Batch 13/17 - Generator Loss: 0.061599306762218475, Discriminator Loss: 0.9365296959877014
# Batch 14/17 - Generator Loss: 0.05346054211258888, Discriminator Loss: 0.9304150342941284
# Batch 15/17 - Generator Loss: 0.022231891751289368, Discriminator Loss: 0.9558113813400269
# Batch 16/17 - Generator Loss: -0.0013461410999298096, Discriminator Loss: 0.9766325354576111
# Batch 17/17 - Generator Loss: -0.02336868643760681, Discriminator Loss: 1.0265650749206543
# Generator - Train: -0.02336868643760681, Val: -0.016407661139965057
# Discriminator - Train: 1.0265650749206543, Val: 1.0106501579284668
# Epoch 2/20
# Batch 1/17 - Generator Loss: -0.017742149531841278, Discriminator Loss: 1.032762050628662
# Batch 2/17 - Generator Loss: -0.027385398745536804, Discriminator Loss: 1.0046944618225098
# Batch 3/17 - Generator Loss: -0.04146471247076988, Discriminator Loss: 1.0387439727783203
# Batch 4/17 - Generator Loss: -0.04262984171509743, Discriminator Loss: 1.0510116815567017
# Batch 5/17 - Generator Loss: -0.05694757401943207, Discriminator Loss: 1.0431301593780518
# Batch 6/17 - Generator Loss: -0.05539971962571144, Discriminator Loss: 1.0532867908477783
# Batch 7/17 - Generator Loss: -0.07002466917037964, Discriminator Loss: 1.0699418783187866
# Batch 8/17 - Generator Loss: -0.07739047706127167, Discriminator Loss: 1.0941431522369385
# Batch 9/17 - Generator Loss: -0.09937778860330582, Discriminator Loss: 1.1058553457260132
# Batch 10/17 - Generator Loss: -0.116671122610569, Discriminator Loss: 1.1404975652694702
# Batch 11/17 - Generator Loss: -0.13838382065296173, Discriminator Loss: 1.1701974868774414
# Batch 12/17 - Generator Loss: -0.15237842500209808, Discriminator Loss: 1.2040784358978271
# Batch 13/17 - Generator Loss: -0.1582057774066925, Discriminator Loss: 1.2149183750152588
# Batch 14/17 - Generator Loss: -0.16119331121444702, Discriminator Loss: 1.22213613986969
# Batch 15/17 - Generator Loss: -0.16532275080680847, Discriminator Loss: 1.2317783832550049
# Batch 16/17 - Generator Loss: -0.1730719953775406, Discriminator Loss: 1.2428284883499146
# Batch 17/17 - Generator Loss: -0.17016924917697906, Discriminator Loss: 1.2413198947906494
# Generator - Train: -0.17016924917697906, Val: -0.1772923618555069
# Discriminator - Train: 1.2413198947906494, Val: 1.267731785774231
# Epoch 3/20
# Batch 1/17 - Generator Loss: -0.18086373805999756, Discriminator Loss: 1.268276572227478
# Batch 2/17 - Generator Loss: -0.18540844321250916, Discriminator Loss: 1.2769594192504883
# Batch 3/17 - Generator Loss: -0.18703791499137878, Discriminator Loss: 1.2875101566314697
# Batch 4/17 - Generator Loss: -0.18733295798301697, Discriminator Loss: 1.3058689832687378
# Batch 5/17 - Generator Loss: -0.19003549218177795, Discriminator Loss: 1.3084558248519897
# Batch 6/17 - Generator Loss: -0.1957266479730606, Discriminator Loss: 1.3175135850906372
# Batch 7/17 - Generator Loss: -0.20003154873847961, Discriminator Loss: 1.3327972888946533
# Batch 8/17 - Generator Loss: -0.20710833370685577, Discriminator Loss: 1.3366913795471191
# Batch 9/17 - Generator Loss: -0.20917963981628418, Discriminator Loss: 1.3454405069351196
# Batch 10/17 - Generator Loss: -0.20972692966461182, Discriminator Loss: 1.3503241539001465
# Batch 11/17 - Generator Loss: -0.21977418661117554, Discriminator Loss: 1.3595815896987915
# Batch 12/17 - Generator Loss: -0.22179235517978668, Discriminator Loss: 1.3653641939163208
# Batch 13/17 - Generator Loss: -0.22393693029880524, Discriminator Loss: 1.3632922172546387
# Batch 14/17 - Generator Loss: -0.22647756338119507, Discriminator Loss: 1.3677492141723633
# Batch 15/17 - Generator Loss: -0.23005430400371552, Discriminator Loss: 1.361135482788086
# Batch 16/17 - Generator Loss: -0.22894559800624847, Discriminator Loss: 1.3533647060394287
# Batch 17/17 - Generator Loss: -0.21753999590873718, Discriminator Loss: 1.3639354705810547
# Generator - Train: -0.21753999590873718, Val: -0.22183041274547577
# Discriminator - Train: 1.3639354705810547, Val: 1.3743304014205933
# Epoch 4/20
# Batch 1/17 - Generator Loss: -0.23459209501743317, Discriminator Loss: 1.3786401748657227
# Batch 2/17 - Generator Loss: -0.2306055724620819, Discriminator Loss: 1.3665857315063477
# Batch 3/17 - Generator Loss: -0.23606622219085693, Discriminator Loss: 1.3682796955108643
# Batch 4/17 - Generator Loss: -0.234574556350708, Discriminator Loss: 1.3754749298095703
# Batch 5/17 - Generator Loss: -0.2368326187133789, Discriminator Loss: 1.3777012825012207
# Batch 6/17 - Generator Loss: -0.23720961809158325, Discriminator Loss: 1.372995376586914
# Batch 7/17 - Generator Loss: -0.23992019891738892, Discriminator Loss: 1.3769567012786865
# Batch 8/17 - Generator Loss: -0.2400263100862503, Discriminator Loss: 1.3781698942184448
# Batch 9/17 - Generator Loss: -0.23934726417064667, Discriminator Loss: 1.375901460647583
# Batch 10/17 - Generator Loss: -0.24039502441883087, Discriminator Loss: 1.3816238641738892
# Batch 11/17 - Generator Loss: -0.24076485633850098, Discriminator Loss: 1.3818539381027222
# Batch 12/17 - Generator Loss: -0.2426486611366272, Discriminator Loss: 1.3806674480438232
# Batch 13/17 - Generator Loss: -0.24245727062225342, Discriminator Loss: 1.3847962617874146
# Batch 14/17 - Generator Loss: -0.24462541937828064, Discriminator Loss: 1.3857684135437012
# Batch 15/17 - Generator Loss: -0.24607069790363312, Discriminator Loss: 1.3869223594665527
# Batch 16/17 - Generator Loss: -0.24483710527420044, Discriminator Loss: 1.3865402936935425
# Batch 17/17 - Generator Loss: -0.24511052668094635, Discriminator Loss: 1.3866060972213745
# Generator - Train: -0.24511052668094635, Val: -0.24536007642745972
# Discriminator - Train: 1.3866060972213745, Val: 1.3866034746170044
# Epoch 5/20
# Batch 1/17 - Generator Loss: -0.24501127004623413, Discriminator Loss: 1.3866015672683716
# Batch 2/17 - Generator Loss: -0.24519744515419006, Discriminator Loss: 1.386574625968933
# Batch 3/17 - Generator Loss: -0.24487321078777313, Discriminator Loss: 1.3866328001022339
# Batch 4/17 - Generator Loss: -0.2448321282863617, Discriminator Loss: 1.3866242170333862
# Batch 5/17 - Generator Loss: -0.24550099670886993, Discriminator Loss: 1.3865364789962769
# Batch 6/17 - Generator Loss: -0.24612343311309814, Discriminator Loss: 1.3863285779953003
# Batch 7/17 - Generator Loss: -0.2457146942615509, Discriminator Loss: 1.3866870403289795
# Batch 8/17 - Generator Loss: -0.24579553306102753, Discriminator Loss: 1.3866955041885376
# Batch 9/17 - Generator Loss: -0.24634987115859985, Discriminator Loss: 1.3866699934005737
# Batch 10/17 - Generator Loss: -0.24590404331684113, Discriminator Loss: 1.3866742849349976
# Batch 11/17 - Generator Loss: -0.24535620212554932, Discriminator Loss: 1.3866957426071167
# Batch 12/17 - Generator Loss: -0.24478250741958618, Discriminator Loss: 1.386699914932251
# Batch 13/17 - Generator Loss: 1.0037976503372192, Discriminator Loss: 2.0399999618530273
# Batch 14/17 - Generator Loss: 1.4010134935379028, Discriminator Loss: 2.0399999618530273
# Batch 15/17 - Generator Loss: 1.4009734392166138, Discriminator Loss: 2.0399999618530273
# Batch 16/17 - Generator Loss: 1.40105140209198, Discriminator Loss: 2.0399999618530273
# Batch 17/17 - Generator Loss: 1.4009467363357544, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.4009467363357544, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Epoch 6/20
# Batch 1/17 - Generator Loss: 1.400952935218811, Discriminator Loss: 2.0399999618530273
# Batch 2/17 - Generator Loss: 1.4011214971542358, Discriminator Loss: 2.0399999618530273
# Batch 3/17 - Generator Loss: 1.4011234045028687, Discriminator Loss: 2.0399999618530273
# Batch 4/17 - Generator Loss: 1.401046872138977, Discriminator Loss: 2.0399999618530273
# Batch 5/17 - Generator Loss: 1.4010032415390015, Discriminator Loss: 2.0399999618530273
# Batch 6/17 - Generator Loss: 1.4009360074996948, Discriminator Loss: 2.0399999618530273
# Batch 7/17 - Generator Loss: 1.401023030281067, Discriminator Loss: 2.0399999618530273
# Batch 8/17 - Generator Loss: 1.4011200666427612, Discriminator Loss: 2.0399999618530273
# Batch 9/17 - Generator Loss: 1.400943636894226, Discriminator Loss: 2.0399999618530273
# Batch 10/17 - Generator Loss: 1.4008945226669312, Discriminator Loss: 2.0399999618530273
# Batch 11/17 - Generator Loss: 1.401065707206726, Discriminator Loss: 2.0399999618530273
# Batch 12/17 - Generator Loss: 1.4009777307510376, Discriminator Loss: 2.0399999618530273
# Batch 13/17 - Generator Loss: 1.4010709524154663, Discriminator Loss: 2.0399999618530273
# Batch 14/17 - Generator Loss: 1.4008620977401733, Discriminator Loss: 2.0399999618530273
# Batch 15/17 - Generator Loss: 1.4011353254318237, Discriminator Loss: 2.0399999618530273
# Batch 16/17 - Generator Loss: 1.4011956453323364, Discriminator Loss: 2.0399999618530273
# Batch 17/17 - Generator Loss: 1.4010118246078491, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.4010118246078491, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Epoch 7/20
# Batch 1/17 - Generator Loss: 1.4011081457138062, Discriminator Loss: 2.0399999618530273
# Batch 2/17 - Generator Loss: 1.4011069536209106, Discriminator Loss: 2.0399999618530273
# Batch 3/17 - Generator Loss: 1.400985836982727, Discriminator Loss: 2.0399999618530273
# Batch 4/17 - Generator Loss: 1.4009839296340942, Discriminator Loss: 2.0399999618530273
# Batch 5/17 - Generator Loss: 1.4012383222579956, Discriminator Loss: 2.0399999618530273
# Batch 6/17 - Generator Loss: 1.4010168313980103, Discriminator Loss: 2.0399999618530273
# Batch 7/17 - Generator Loss: 1.4007374048233032, Discriminator Loss: 2.0399999618530273
# Batch 8/17 - Generator Loss: 1.40121591091156, Discriminator Loss: 2.0399999618530273
# Batch 9/17 - Generator Loss: 1.4009085893630981, Discriminator Loss: 2.0399999618530273
# Batch 10/17 - Generator Loss: 1.4008592367172241, Discriminator Loss: 2.0399999618530273
# Batch 11/17 - Generator Loss: 1.4008437395095825, Discriminator Loss: 2.0399999618530273
# Batch 12/17 - Generator Loss: 1.4011305570602417, Discriminator Loss: 2.0399999618530273
# Batch 13/17 - Generator Loss: 1.4011362791061401, Discriminator Loss: 2.0399999618530273
# Batch 14/17 - Generator Loss: 1.400941252708435, Discriminator Loss: 2.0399999618530273
# Batch 15/17 - Generator Loss: 1.4010928869247437, Discriminator Loss: 2.0399999618530273
# Batch 16/17 - Generator Loss: 1.4009002447128296, Discriminator Loss: 2.0399999618530273
# Batch 17/17 - Generator Loss: 1.4009805917739868, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.4009805917739868, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Epoch 8/20
# Batch 1/17 - Generator Loss: 1.4010316133499146, Discriminator Loss: 2.0399999618530273
# Batch 2/17 - Generator Loss: 1.4011234045028687, Discriminator Loss: 2.0399999618530273
# Batch 3/17 - Generator Loss: 1.4010907411575317, Discriminator Loss: 2.0399999618530273
# Batch 4/17 - Generator Loss: 1.4012523889541626, Discriminator Loss: 2.0399999618530273
# Batch 5/17 - Generator Loss: 1.4009939432144165, Discriminator Loss: 2.0399999618530273
# Batch 6/17 - Generator Loss: 1.4010237455368042, Discriminator Loss: 2.0399999618530273
# Batch 7/17 - Generator Loss: 1.400941252708435, Discriminator Loss: 2.0399999618530273
# Batch 8/17 - Generator Loss: 1.4012058973312378, Discriminator Loss: 2.0399999618530273
# Batch 9/17 - Generator Loss: 1.4011136293411255, Discriminator Loss: 2.0399999618530273
# Batch 10/17 - Generator Loss: 1.4009190797805786, Discriminator Loss: 2.0399999618530273
# Batch 11/17 - Generator Loss: 1.401077151298523, Discriminator Loss: 2.0399999618530273
# Batch 12/17 - Generator Loss: 1.400983214378357, Discriminator Loss: 2.0399999618530273
# Batch 13/17 - Generator Loss: 1.4009052515029907, Discriminator Loss: 2.0399999618530273
# Batch 14/17 - Generator Loss: 1.401157259941101, Discriminator Loss: 2.0399999618530273
# Batch 15/17 - Generator Loss: 1.4008640050888062, Discriminator Loss: 2.0399999618530273
# Batch 16/17 - Generator Loss: 1.4009653329849243, Discriminator Loss: 2.0399999618530273
# Batch 17/17 - Generator Loss: 1.4011071920394897, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.4011071920394897, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Epoch 9/20
# Batch 1/17 - Generator Loss: 1.4012113809585571, Discriminator Loss: 2.0399999618530273
# Batch 2/17 - Generator Loss: 1.4011505842208862, Discriminator Loss: 2.0399999618530273
# Batch 3/17 - Generator Loss: 1.4009288549423218, Discriminator Loss: 2.0399999618530273
# Batch 4/17 - Generator Loss: 1.4010709524154663, Discriminator Loss: 2.0399999618530273
# Batch 5/17 - Generator Loss: 1.4011789560317993, Discriminator Loss: 2.0399999618530273
# Batch 6/17 - Generator Loss: 1.4009567499160767, Discriminator Loss: 2.0399999618530273
# Batch 7/17 - Generator Loss: 1.4008785486221313, Discriminator Loss: 2.0399999618530273
# Batch 8/17 - Generator Loss: 1.4009042978286743, Discriminator Loss: 2.0399999618530273
# Batch 9/17 - Generator Loss: 1.4009171724319458, Discriminator Loss: 2.0399999618530273
# Batch 10/17 - Generator Loss: 1.4010611772537231, Discriminator Loss: 2.0399999618530273
# Batch 11/17 - Generator Loss: 1.4009581804275513, Discriminator Loss: 2.0399999618530273
# Batch 12/17 - Generator Loss: 1.4009801149368286, Discriminator Loss: 2.0399999618530273
# Batch 13/17 - Generator Loss: 1.401063323020935, Discriminator Loss: 2.0399999618530273
# Batch 14/17 - Generator Loss: 1.4011105298995972, Discriminator Loss: 2.0399999618530273
# Batch 15/17 - Generator Loss: 1.4009870290756226, Discriminator Loss: 2.0399999618530273
# Batch 16/17 - Generator Loss: 1.4009000062942505, Discriminator Loss: 2.0399999618530273
# Batch 17/17 - Generator Loss: 1.4011603593826294, Discriminator Loss: 2.0399999618530273
# Generator - Train: 1.4011603593826294, Val: 1.4004968404769897
# Discriminator - Train: 2.0399999618530273, Val: 2.0399999618530273
# Early stopping at epoch 9. No improvement for 5 consecutive epochs.
# Best validation loss: -0.24536007642745972 at epoch 4

# %%
gan.visualize_loss()

# %%
gan.visualize_generator_loss_components()

# %%
i=10

X = X_train[i]
z = X_train_z[i]
cX = cX_train[i]

a = gan.generate(X, z, cX)[0]

a.max(), a.min(), a.mean(), X_train[i].max(), X_train[i].min(), X_train[i].mean()
# Out:
# (0.9959099, 0.07638856, 0.3645966, 1.0, 0.0, 0.36163604)

# %%
for i in range(2, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    gan.visualize_generated_image(X, z, cX)

# %%
for i in range(4, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    a = gan.generate(X, z, cX)

    from src.utils.optical_flow import draw_optical_flow

    draw_optical_flow(X[0], X[1])
    for i in range(len_generated_seq-1):
        draw_optical_flow(a[0][i], a[0][i+1])

# %%
from skimage import img_as_ubyte
import imageio
import numpy as np

def generate_gif(images, name):
    images = [img_as_ubyte(image) for image in images]
    images = [np.transpose(image, (1, 2, 0)) for image in images]
    imageio.mimsave(f'{name}.gif', images)

def generate_gif_gray(images, name):
    images = [img_as_ubyte(image) for image in images]
    imageio.mimsave(f'{name}.gif', images)

for i in range(0, X_val.shape[0]):
    X = X_val[i]
    z = X_val_z[i]
    cX = cX_val[i]

    images_list = gan.generate(X, z, cX)[0]

    images_list = np.concatenate((X, images_list), axis=0)

    # image to gray scale
    images_list_bw = np.zeros((images_list.shape[0], images_list.shape[2], images_list.shape[3]))
    for j in range(images_list.shape[0]):
        images_list_bw[j] = np.mean(images_list[j], axis=0)

    generate_gif_gray(images_list_bw, f'generated_images/generated_gif_obj/generated_sample_{i}')
