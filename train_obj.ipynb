# %%
from src.wgan import WassersteinGAN

from src.utils.make_discriminator import make_discriminator
from src.utils.make_generator import make_generator
# Out:
# c:\Users\giuli\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Data

# %%
len_input_seq = 2
len_generated_seq = 2
#X_train, X_val, X_test, X_train_z, X_val_z, X_test_z, cX_train, cX_val, cX_test = get_gan_dataset(len_input_seq)

# %%
def get_data():
    import pickle

    with open('data/new_data_obj.pkl', 'rb') as f:
        X_train, cX_train, X_train_z = pickle.load(f)

    # split the training set into training and validation
    n_sample_train = int(X_train.shape[0] * 0.8)

    X_train, X_val = X_train[:n_sample_train], X_train[n_sample_train:]
    cX_train, cX_val = cX_train[:n_sample_train], cX_train[n_sample_train:]
    X_train_z, X_val_z = X_train_z[:n_sample_train], X_train_z[n_sample_train:]

    len_input_seq = X_train.shape[1] # 6
    len_generated_seq = 4

    return X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq

X_train, X_val, X_train_z, X_val_z, cX_train, cX_val, len_input_seq, len_generated_seq = get_data()

# %% [markdown]
# ### Models

# %%
generator = make_generator(
    image_dim=[3, 64, 64],
    latent_dim=1280,
    conditions_dim=6,
    len_input_seq=len_input_seq,
    len_output_seq=len_generated_seq,
    n_filters=[16, 8, 8],
    kernel_size=[5, 3, 1],
    stride=[1, 1, 1],
    padding=['same', 'same', 'same'],
    hidden_dims=[128, 128],
)

discriminator = make_discriminator(
    input_dim=[3, 64, 64],
    len_input_seq=min(len_input_seq, len_generated_seq),
)

gan = WassersteinGAN(
    generator=generator,
    discriminator=discriminator,
    len_input_seq=len_input_seq,
    len_generated_seq=len_generated_seq,
    patience=5,
    learning_rate_generator=0.01,
    learning_rate_discriminator=0.01,
    n_critic=5,  # number of critic updates per generator update
    clip_value=0.01,
    discriminator_gradient_penalty_weight=0.02,
    generator_wloss_weight=0.5,
    generator_flow_loss_weight=0.3,
    generator_mse_weight=0.15,
    color_weight=0.05,
    save_path = 'wgan_train_obj'
)

# %% [markdown]
# ### Train

# %%
gan.train(
    X_train_z, X_train, cX_train, # noise, real images, conditions
    X_val_z, X_val, cX_val,
    epochs=20, batch_size=32
)
# Out:
# Epoch 1/20
# Batch 1/17 - Generator Loss: 0.03904927521944046, Discriminator Loss: 1.290865182876587
# Batch 2/17 - Generator Loss: 0.06828755140304565, Discriminator Loss: 0.9397892355918884
# Batch 3/17 - Generator Loss: 0.01687077060341835, Discriminator Loss: 0.9540318846702576
# Batch 4/17 - Generator Loss: -0.013127319514751434, Discriminator Loss: 0.9814950823783875
# Batch 5/17 - Generator Loss: -0.014496609568595886, Discriminator Loss: 0.9776163101196289
# Batch 6/17 - Generator Loss: -0.029345087707042694, Discriminator Loss: 0.989937961101532
# Batch 7/17 - Generator Loss: -0.030496295541524887, Discriminator Loss: 0.9801031351089478
# Batch 8/17 - Generator Loss: -0.04166465252637863, Discriminator Loss: 0.9992740154266357
# Batch 9/17 - Generator Loss: -0.04615909606218338, Discriminator Loss: 1.0269243717193604
# Batch 10/17 - Generator Loss: -0.05921107903122902, Discriminator Loss: 1.0313771963119507
# Batch 11/17 - Generator Loss: -0.05767706409096718, Discriminator Loss: 1.038743495941162
# Batch 12/17 - Generator Loss: -0.07268477976322174, Discriminator Loss: 1.04625403881073
# Batch 13/17 - Generator Loss: -0.07092137634754181, Discriminator Loss: 1.0602895021438599
# Batch 14/17 - Generator Loss: -0.07352963089942932, Discriminator Loss: 1.0542802810668945
# Batch 15/17 - Generator Loss: -0.0772150307893753, Discriminator Loss: 1.0555928945541382
# Batch 16/17 - Generator Loss: -0.08296284824609756, Discriminator Loss: 1.0629708766937256
# Batch 17/17 - Generator Loss: -0.10004203766584396, Discriminator Loss: 1.0832911729812622
# Generator - Train: -0.10004203766584396, Val: -0.0977313369512558
# Discriminator - Train: 1.0832911729812622, Val: 1.07275390625
# Epoch 2/20
# Batch 1/17 - Generator Loss: -0.09534437954425812, Discriminator Loss: 1.0746338367462158
# Batch 2/17 - Generator Loss: -0.09727462381124496, Discriminator Loss: 1.0771809816360474
# Batch 3/17 - Generator Loss: -0.09733763337135315, Discriminator Loss: 1.0861666202545166
# Batch 4/17 - Generator Loss: -0.10396049916744232, Discriminator Loss: 1.1093652248382568
# Batch 5/17 - Generator Loss: -0.10953870415687561, Discriminator Loss: 1.117990255355835
# Batch 6/17 - Generator Loss: -0.10505231469869614, Discriminator Loss: 1.0965971946716309
# Batch 7/17 - Generator Loss: -0.11241727322340012, Discriminator Loss: 1.1053320169448853
# Batch 8/17 - Generator Loss: -0.11785247921943665, Discriminator Loss: 1.1148840188980103
# Batch 9/17 - Generator Loss: -0.11486971378326416, Discriminator Loss: 1.1232128143310547
# Batch 10/17 - Generator Loss: -0.1212516725063324, Discriminator Loss: 1.1411200761795044
# Batch 11/17 - Generator Loss: -0.1278037279844284, Discriminator Loss: 1.147950530052185
# Batch 12/17 - Generator Loss: -0.12892726063728333, Discriminator Loss: 1.1527179479599
# Batch 13/17 - Generator Loss: -0.12158042192459106, Discriminator Loss: 1.1335339546203613
# Batch 14/17 - Generator Loss: -0.1331261545419693, Discriminator Loss: 1.1451143026351929
# Batch 15/17 - Generator Loss: -0.13709218800067902, Discriminator Loss: 1.148613691329956
# Batch 16/17 - Generator Loss: -0.13758455216884613, Discriminator Loss: 1.1632498502731323
# Batch 17/17 - Generator Loss: -0.138255774974823, Discriminator Loss: 1.159041404724121
# Generator - Train: -0.138255774974823, Val: -0.1398065984249115
# Discriminator - Train: 1.159041404724121, Val: 1.1677874326705933
# Epoch 3/20
# Batch 1/17 - Generator Loss: -0.1398053914308548, Discriminator Loss: 1.1747262477874756
# Batch 2/17 - Generator Loss: -0.13334740698337555, Discriminator Loss: 1.1769500970840454
# Batch 3/17 - Generator Loss: -0.14326637983322144, Discriminator Loss: 1.1760004758834839
# Batch 4/17 - Generator Loss: -0.14485549926757812, Discriminator Loss: 1.1870781183242798
# Batch 5/17 - Generator Loss: -0.14330068230628967, Discriminator Loss: 1.1957727670669556
# Batch 6/17 - Generator Loss: -0.14270099997520447, Discriminator Loss: 1.1791106462478638
# Batch 7/17 - Generator Loss: -0.1505771428346634, Discriminator Loss: 1.1898401975631714
# Batch 8/17 - Generator Loss: -0.15489304065704346, Discriminator Loss: 1.2030261754989624
# Batch 9/17 - Generator Loss: -0.15498211979866028, Discriminator Loss: 1.2030178308486938
# Batch 10/17 - Generator Loss: -0.15499615669250488, Discriminator Loss: 1.1976293325424194
# Batch 11/17 - Generator Loss: -0.15024670958518982, Discriminator Loss: 1.1998450756072998
# Batch 12/17 - Generator Loss: -0.1578889936208725, Discriminator Loss: 1.2130950689315796
# Batch 13/17 - Generator Loss: -0.1562686711549759, Discriminator Loss: 1.231773018836975
# Batch 14/17 - Generator Loss: -0.1501050889492035, Discriminator Loss: 1.2147724628448486
# Batch 15/17 - Generator Loss: -0.1593785583972931, Discriminator Loss: 1.2128618955612183
# Batch 16/17 - Generator Loss: -0.16003237664699554, Discriminator Loss: 1.227797508239746
# Batch 17/17 - Generator Loss: -0.16015318036079407, Discriminator Loss: 1.2359338998794556
# Generator - Train: -0.16015318036079407, Val: -0.16284064948558807
# Discriminator - Train: 1.2359338998794556, Val: 1.2289139032363892
# Epoch 4/20
# Batch 1/17 - Generator Loss: -0.15694792568683624, Discriminator Loss: 1.237789273262024
# Batch 2/17 - Generator Loss: -0.16499440371990204, Discriminator Loss: 1.225043773651123
# Batch 3/17 - Generator Loss: -0.16587501764297485, Discriminator Loss: 1.252909779548645
# Batch 4/17 - Generator Loss: -0.1630108654499054, Discriminator Loss: 1.240784764289856
# Batch 5/17 - Generator Loss: -0.1680162400007248, Discriminator Loss: 1.2360554933547974
# Batch 6/17 - Generator Loss: -0.17198508977890015, Discriminator Loss: 1.2440431118011475
# Batch 7/17 - Generator Loss: -0.17263521254062653, Discriminator Loss: 1.251160979270935
# Batch 8/17 - Generator Loss: -0.16657964885234833, Discriminator Loss: 1.255454659461975
# Batch 9/17 - Generator Loss: -0.1756204217672348, Discriminator Loss: 1.2633895874023438
# Batch 10/17 - Generator Loss: -0.1749703586101532, Discriminator Loss: 1.2627547979354858
# Batch 11/17 - Generator Loss: -0.17073336243629456, Discriminator Loss: 1.2588049173355103
# Batch 12/17 - Generator Loss: -0.17718569934368134, Discriminator Loss: 1.2722537517547607
# Batch 13/17 - Generator Loss: -0.18121054768562317, Discriminator Loss: 1.278707504272461
# Batch 14/17 - Generator Loss: -0.17625866830348969, Discriminator Loss: 1.2713979482650757
# Batch 15/17 - Generator Loss: -0.18295517563819885, Discriminator Loss: 1.2865170240402222
# Batch 16/17 - Generator Loss: -0.18430453538894653, Discriminator Loss: 1.2823737859725952
# Batch 17/17 - Generator Loss: -0.1832118183374405, Discriminator Loss: 1.2864060401916504
# Generator - Train: -0.1832118183374405, Val: -0.1859809011220932
# Discriminator - Train: 1.2864060401916504, Val: 1.2869676351547241
# Epoch 5/20
# Batch 1/17 - Generator Loss: -0.18591418862342834, Discriminator Loss: 1.2843352556228638
# Batch 2/17 - Generator Loss: -0.18927954137325287, Discriminator Loss: 1.2917064428329468
# Batch 3/17 - Generator Loss: -0.1905141919851303, Discriminator Loss: 1.2955448627471924
# Batch 4/17 - Generator Loss: -0.19124634563922882, Discriminator Loss: 1.3133653402328491
# Batch 5/17 - Generator Loss: -0.19440215826034546, Discriminator Loss: 1.3135918378829956
# Batch 6/17 - Generator Loss: -0.19723503291606903, Discriminator Loss: 1.3147224187850952
# Batch 7/17 - Generator Loss: -0.19971781969070435, Discriminator Loss: 1.3257367610931396
# Batch 8/17 - Generator Loss: -0.1984671652317047, Discriminator Loss: 1.3350342512130737
# Batch 9/17 - Generator Loss: -0.2036304622888565, Discriminator Loss: 1.337559461593628
# Batch 10/17 - Generator Loss: -0.20311002433300018, Discriminator Loss: 1.3399057388305664
# Batch 11/17 - Generator Loss: -0.20792822539806366, Discriminator Loss: 1.3404656648635864
# Batch 12/17 - Generator Loss: -0.2087390273809433, Discriminator Loss: 1.3494107723236084
# Batch 13/17 - Generator Loss: -0.2129381000995636, Discriminator Loss: 1.3553907871246338
# Batch 14/17 - Generator Loss: -0.21067307889461517, Discriminator Loss: 1.3605737686157227
# Batch 15/17 - Generator Loss: -0.21612821519374847, Discriminator Loss: 1.3668676614761353
# Batch 16/17 - Generator Loss: -0.21830956637859344, Discriminator Loss: 1.3683127164840698
# Batch 17/17 - Generator Loss: -0.21719783544540405, Discriminator Loss: 1.3687434196472168
# Generator - Train: -0.21719783544540405, Val: -0.21813128888607025
# Discriminator - Train: 1.3687434196472168, Val: 1.3689628839492798
# Epoch 6/20
# Batch 1/17 - Generator Loss: -0.21849027276039124, Discriminator Loss: 1.3691538572311401
# Batch 2/17 - Generator Loss: -0.22028152644634247, Discriminator Loss: 1.3744323253631592
# Batch 3/17 - Generator Loss: -0.22147074341773987, Discriminator Loss: 1.3752275705337524
# Batch 4/17 - Generator Loss: -0.22108152508735657, Discriminator Loss: 1.3770948648452759
# Batch 5/17 - Generator Loss: -0.22321370244026184, Discriminator Loss: 1.3778237104415894
# Batch 6/17 - Generator Loss: -0.22486612200737, Discriminator Loss: 1.378617286682129
# Batch 7/17 - Generator Loss: -0.22513799369335175, Discriminator Loss: 1.3798524141311646
# Batch 8/17 - Generator Loss: -0.22583773732185364, Discriminator Loss: 1.378330111503601
# Batch 9/17 - Generator Loss: -0.22676782310009003, Discriminator Loss: 1.3798906803131104
# Batch 10/17 - Generator Loss: -0.22799138724803925, Discriminator Loss: 1.380509614944458
# Batch 11/17 - Generator Loss: -0.2279859483242035, Discriminator Loss: 1.3799128532409668
# Batch 12/17 - Generator Loss: -0.23010365664958954, Discriminator Loss: 1.3802568912506104
# Batch 13/17 - Generator Loss: -0.2286427617073059, Discriminator Loss: 1.3808237314224243
# Batch 14/17 - Generator Loss: -0.23152652382850647, Discriminator Loss: 1.3824180364608765
# Batch 15/17 - Generator Loss: -0.23173591494560242, Discriminator Loss: 1.381917119026184
# Batch 16/17 - Generator Loss: -0.23288778960704803, Discriminator Loss: 1.3814834356307983
# Batch 17/17 - Generator Loss: -0.23442091047763824, Discriminator Loss: 1.3838590383529663
# Generator - Train: -0.23442091047763824, Val: -0.2353980839252472
# Discriminator - Train: 1.3838590383529663, Val: 1.3838261365890503
# Epoch 7/20
# Batch 1/17 - Generator Loss: -0.2351273000240326, Discriminator Loss: 1.3839433193206787
# Batch 2/17 - Generator Loss: -0.23577101528644562, Discriminator Loss: 1.38538658618927
# Batch 3/17 - Generator Loss: -0.23698458075523376, Discriminator Loss: 1.3848930597305298
# Batch 4/17 - Generator Loss: -0.23762117326259613, Discriminator Loss: 1.3852664232254028
# Batch 5/17 - Generator Loss: -0.238390251994133, Discriminator Loss: 1.3851238489151
# Batch 6/17 - Generator Loss: -0.2390032857656479, Discriminator Loss: 1.3855400085449219
# Batch 7/17 - Generator Loss: -0.2398749589920044, Discriminator Loss: 1.3861620426177979
# Batch 8/17 - Generator Loss: -0.2397814840078354, Discriminator Loss: 1.3863686323165894
# Batch 9/17 - Generator Loss: -0.24086347222328186, Discriminator Loss: 1.3862837553024292
# Batch 10/17 - Generator Loss: -0.24032443761825562, Discriminator Loss: 1.3863719701766968
# Batch 11/17 - Generator Loss: -0.24105821549892426, Discriminator Loss: 1.386712908744812
# Batch 12/17 - Generator Loss: -0.2419557422399521, Discriminator Loss: 1.3866273164749146
# Batch 13/17 - Generator Loss: -0.24203959107398987, Discriminator Loss: 1.3866276741027832
# Batch 14/17 - Generator Loss: -0.2423480898141861, Discriminator Loss: 1.3866368532180786
# Batch 15/17 - Generator Loss: -0.24296338856220245, Discriminator Loss: 1.386654019355774
# Batch 16/17 - Generator Loss: -0.2430371344089508, Discriminator Loss: 1.386684536933899
# Batch 17/17 - Generator Loss: -0.2429952323436737, Discriminator Loss: 1.38668954372406
# Generator - Train: -0.2429952323436737, Val: -0.2435183823108673
# Discriminator - Train: 1.38668954372406, Val: 1.3866909742355347
# Epoch 8/20
# Batch 1/17 - Generator Loss: -0.24297402799129486, Discriminator Loss: 1.3867100477218628
# Training stopped due to None loss value

# %%
gan.visualize_loss()

# %%
gan.visualize_generator_loss_components()

# %%
i=10

X = X_train[i]
z = X_train_z[i]
cX = cX_train[i]

a = gan.generate(X, z, cX)[0]

a.max(), a.min(), a.mean(), X_train[i].max(), X_train[i].min(), X_train[i].mean()
# Out:
# (0.99867386, 0.1609549, 0.34425926, 1.0, 0.0, 0.36163604)

# %%
for i in range(2, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    gan.visualize_generated_image(X, z, cX)

# %%
for i in range(4, 5):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    a = gan.generate(X, z, cX)

    from src.utils.optical_flow import draw_optical_flow

    draw_optical_flow(X[0], X[1])
    for i in range(len_generated_seq-1):
        draw_optical_flow(a[0][i], a[0][i+1])

# %%
from skimage import img_as_ubyte
import imageio
import numpy as np

def generate_gif(images, name):
    images = [img_as_ubyte(image) for image in images]
    images = [np.transpose(image, (1, 2, 0)) for image in images]
    imageio.mimsave(f'{name}.gif', images)

def generate_gif_gray(images, name):
    images = [img_as_ubyte(image) for image in images]
    imageio.mimsave(f'{name}.gif', images)

for i in range(0, X_train.shape[0]):
    X = X_train[i]
    z = X_train_z[i]
    cX = cX_train[i]

    images_list = gan.generate(X, z, cX)[0]

    images_list = np.concatenate((X, images_list), axis=0)

    # image to gray scale
    images_list_bw = np.zeros((images_list.shape[0], images_list.shape[2], images_list.shape[3]))
    for j in range(images_list.shape[0]):
        images_list_bw[j] = np.mean(images_list[j], axis=0)

    generate_gif_gray(images_list_bw, f'generated_images/generated_gif_obj/generated_sample_{i}')
